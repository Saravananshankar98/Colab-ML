# %% [markdown]
# <a href="https://colab.research.google.com/github/Saravananshankar98/Colab-ML/blob/main/pandas_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
d1= {
"name": ["mani", "vijay", "ajith"],
"age": [18,21,22],
"mark": [90,95,56]
}
df1=pd.DataFrame(d1)
print(df1)
# Out:
#     name  age  mark
# 0   mani   18    90
# 1  vijay   21    95
# 2  ajith   22    56

# %%
df1.to_csv("student.csv", index=False)

# %%
student = pd.read_csv("student.csv")
print(student)
# Out:
#     name  age  mark
# 0   mani   18    90
# 1  vijay   21    95
# 2  ajith   22    56

# %%
student.describe()
# Out:
#              age       mark
# count   3.000000   3.000000
# mean   20.333333  80.333333
# std     2.081666  21.221059
# min    18.000000  56.000000
# 25%    19.500000  73.000000
# 50%    21.000000  90.000000
# 75%    21.500000  92.500000
# max    22.000000  95.000000

# %%
name = pd.Series(["mani", "vijay", "ajith"])
age = pd.Series([18,21,22])
course = pd.Series(["python", "java", "c"])
df2 = pd.DataFrame({"name": name, "age": age, "course": course})
print(df2)
# Out:
#     name  age  course
# 0   mani   18  python
# 1  vijay   21    java
# 2  ajith   22       c

# %%
df2.iloc[[0,2]]
# Out:
#        index   name  age  course
# first  first   mani   18  python
# third  third  ajith   22       c

# %%
df2.index =["first", "second", "third"]
df2.loc[["second", "third"]]
# df2.set_index("name", inplace=True)
# print(df2)

# df2.reset_index(inplace=True)
# print(df2)
# Out:
#          index   name  age course
# second  second  vijay   21   java
# third    third  ajith   22      c

# %%
df2.reset_index(inplace=True)
print(df2)
# Out:
#    index   name  age  course
# 0      0   mani   18  python
# 1      1  vijay   21    java
# 2      2  ajith   22       c
